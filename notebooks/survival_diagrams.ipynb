# %%
import pandas as pd

# %%
commit_sharings_changes_survival_df = pd.read_csv('commit_sharings_changes_survival_df.csv')

# %%
pr_sharings_changes_survival_df = pd.read_csv('pr_sharings_changes_survival_df.csv')

# %%
issue_sharings_changes_survival_df = pd.read_csv('issue_sharings_changes_survival_df.csv')

# %%
commit_sharings_changes_survival_df.head()
# Out:
#      Type                                                URL       Author  \
# 0  commit  https://github.com/grnpin/textbox/commit/fa335...       grnpin
# 1  commit  https://github.com/grnpin/textbox/commit/0dfc4...       grnpin
# 2  commit  https://github.com/grnpin/textbox/commit/811d0...       grnpin
# 3  commit  https://github.com/bh679/MindfulAI2.0/commit/e...        bh679
# 4  commit  https://github.com/4lejandrito/fetchbook/commi...  4lejandrito
#
#                 RepoName RepoLanguage  \
# 0         grnpin/textbox         HTML
# 1         grnpin/textbox         HTML
# 2         grnpin/textbox         HTML
# 3     bh679/MindfulAI2.0          CSS
# 4  4lejandrito/fetchbook   JavaScript
#
#                                         Sha  \
# 0  fa335cf2ec447d00f8e94b54a8b463725b92947c
# 1  0dfc4385b723060e1e6a21da17a952bd908084ff
# 2  811d09acdca361c81281c7d71587ebdbd8437453
# 3  e4a8c0fe3adfefb5922315c5b9df3c9cc4c0cff6
# 4  11725c1a23503f31f7b7cd13188c8d9e30e822a9
#
# ...

# %%
commit_sharings_changes_survival_df.columns
# Out:
# Index(['Type', 'URL', 'Author', 'RepoName', 'RepoLanguage', 'Sha', 'Message',
#        'AuthorAt', 'CommitAt', 'NumberOfChatgptSharings',
#        'TotalNumberOfPrompts', 'TotalTokensOfPrompts', 'TotalTokensOfAnswers',
#        'NumberOfConversations', 'ModelGPT4', 'ModelGPT3_5', 'ModelOther',
#        'Status404', 'Sha_is_valid', 'author_timestamp', 'committer_timestamp',
#        'n_parents', 'is_merged_HEAD', 'number_of_commits_from_HEAD', 'error',
#        'change_lines_survived', 'change_lines_total',
#        'min_died_committer_timestamp'],
#       dtype='object')

# %%
commit_sharings_changes_survival_df[commit_sharings_changes_survival_df['error']==True].shape
# Out:
# (5, 28)

# %%
commit_sharings_changes_survival_df[commit_sharings_changes_survival_df['error']==True]
# Out:
#        Type                                                URL  \
# 24   commit  https://github.com/bulatkhu/programmierung-und...
# 25   commit  https://github.com/bulatkhu/programmierung-und...
# 254  commit  https://github.com/Loknar/loka-ord/commit/cf96...
# 345  commit  https://github.com/tisztamo/Junior/commit/c3e5...
# 652  commit  https://github.com/repeatingbeats/dotfiles/com...
#
#              Author                                         RepoName  \
# 24         bulatkhu  bulatkhu/programmierung-und-programmiersprachen
# 25         bulatkhu  bulatkhu/programmierung-und-programmiersprachen
# 254          Loknar                                  Loknar/loka-ord
# 345        tisztamo                                  tisztamo/Junior
# 652  repeatingbeats                          repeatingbeats/dotfiles
#
#     RepoLanguage                                       Sha  \
# 24          Java  facee555ab88d879f6c2befd9bd5f2c1e77273f4
# ...

# %%
commit_sharings_changes_survival_df[commit_sharings_changes_survival_df['error']==True]
# Out:
#        Type                                                URL  \
# 24   commit  https://github.com/bulatkhu/programmierung-und...
# 25   commit  https://github.com/bulatkhu/programmierung-und...
# 254  commit  https://github.com/Loknar/loka-ord/commit/cf96...
# 345  commit  https://github.com/tisztamo/Junior/commit/c3e5...
# 652  commit  https://github.com/repeatingbeats/dotfiles/com...
#
#              Author                                         RepoName  \
# 24         bulatkhu  bulatkhu/programmierung-und-programmiersprachen
# 25         bulatkhu  bulatkhu/programmierung-und-programmiersprachen
# 254          Loknar                                  Loknar/loka-ord
# 345        tisztamo                                  tisztamo/Junior
# 652  repeatingbeats                          repeatingbeats/dotfiles
#
#     RepoLanguage                                       Sha  \
# 24          Java  facee555ab88d879f6c2befd9bd5f2c1e77273f4
# ...

# %%
commit_sharings_changes_survival_df[commit_sharings_changes_survival_df['error']==False].shape
# Out:
# (691, 28)

# %%
commit_sharings_changes_survival_df[commit_sharings_changes_survival_df['error']==True].shape
# Out:
# (5, 28)

# %%
pr_sharings_changes_survival_df[pr_sharings_changes_survival_df['error']==False].shape
# Out:
# (182, 46)

# %%
pr_sharings_changes_survival_df[pr_sharings_changes_survival_df['error']==True].shape
# Out:
# (4, 46)

# %%
issue_sharings_changes_survival_df[issue_sharings_changes_survival_df['error']==False].shape
# Out:
# (69, 42)

# %%
issue_sharings_changes_survival_df[issue_sharings_changes_survival_df['error']==True].shape
# Out:
# (0, 42)

# %%
non_error_pr = pr_sharings_changes_survival_df[pr_sharings_changes_survival_df['error']==False]

# %%
non_error_issue = issue_sharings_changes_survival_df[issue_sharings_changes_survival_df['error']==False]

# %%
non_error_commit = commit_sharings_changes_survival_df[commit_sharings_changes_survival_df['error']==False]

# %%
non_error[['TotalNumberOfPrompts','NumberOfConversations','is_merged_HEAD','change_lines_survived','change_lines_total']].describe()
# Out:
#        TotalNumberOfPrompts  NumberOfConversations  change_lines_survived  \
# count            691.000000             691.000000             691.000000
# mean               2.797395               2.337192             188.920405
# std                4.868954               4.695115            2955.876717
# min                0.000000               0.000000               0.000000
# 25%                1.000000               1.000000               2.000000
# 50%                1.000000               1.000000              18.000000
# 75%                2.000000               1.000000              76.500000
# max               64.000000              63.000000           77301.000000
#
#        change_lines_total
# count          691.000000
# mean           245.610709
# std           2966.866913
# min              0.000000
# 25%             41.000000
# 50%             79.000000
# 75%            129.500000
# max          77344.000000

# %%
from scipy.stats import bootstrap

# %%
import numpy as np

# %%
res = bootstrap((non_error_commit['TotalNumberOfPrompts'],), np.std, confidence_level=0.95)

# %%
res
# Out:
# BootstrapResult(confidence_interval=ConfidenceInterval(low=3.868809122208525, high=6.701369246354307), bootstrap_distribution=array([5.15995858, 4.86272439, 4.69427159, ..., 3.64446546, 5.36569851,
#        5.58665857]), standard_error=0.6578364411704305)

# %%
res.confidence_interval
# Out:
# ConfidenceInterval(low=3.868809122208525, high=6.701369246354307)

# %%
def print_bootstrap_low_high(df, column):
    low, high = bootstrap((df[column],), np.std, confidence_level=0.95).confidence_interval
    print(round(low, 2))
    print(round(high, 2))

# %%
def print_low_high(df):
    print_bootstrap_low_high(df, 'TotalNumberOfPrompts')
    print_bootstrap_low_high(df, 'NumberOfConversations')
    print_bootstrap_low_high(df, 'TotalTokensOfPrompts')
    print_bootstrap_low_high(df, 'TotalTokensOfAnswers')

# %%
print_low_high(non_error_commit)
# Out:
# 3.89
# 6.82
# 3.73
# 6.61
# 632.13
# 1434.3
# 1318.01
# 2302.25

# %%
print_low_high(non_error_pr)
# Out:
# 4.39
# 27.32
# 4.03
# 29.43
# 2370.43
# 6683.86
# 2533.92
# 8732.89

# %%
print_low_high(non_error_issue)
# Out:
# 3.03
# 10.94
# 2.69
# 10.71
# 485.33
# 1264.92
# 934.77
# 3179.52

# %%
bootstrap((non_error_commit['TotalNumberOfPrompts'],), np.std, confidence_level=0.95).confidence_interval
# Out:
# ConfidenceInterval(low=3.8691966243381, high=6.786176008785187)

# %%
bootstrap((non_error_commit['NumberOfConversations'],), np.std, confidence_level=0.95).confidence_interval
# Out:
# ConfidenceInterval(low=3.720252487848247, high=6.604313825392041)

# %%
bootstrap((non_error_commit['TotalTokensOfPrompts'],), np.std, confidence_level=0.95).confidence_interval
# Out:
# ConfidenceInterval(low=641.9626068298721, high=1433.5847989341491)

# %%
bootstrap((non_error_commit['TotalTokensOfAnswers'],), np.std, confidence_level=0.95).confidence_interval
# Out:
# ConfidenceInterval(low=1326.5869340762306, high=2279.3618505557324)

# %%
bootstrap((non_error_pr['TotalNumberOfPrompts'],), np.std, confidence_level=0.95).confidence_interval
# Out:
# ConfidenceInterval(low=4.381939410729972, high=30.74593039710458)

# %%
bootstrap((non_error_pr['NumberOfConversations'],), np.std, confidence_level=0.95).confidence_interval
# Out:
# ConfidenceInterval(low=4.038405283348134, high=29.421409199961165)

# %%
bootstrap((non_error_pr['TotalTokensOfPrompts'],), np.std, confidence_level=0.95).confidence_interval
# Out:
# ConfidenceInterval(low=2394.662382825438, high=6850.99762051514)

# %%
bootstrap((non_error_pr['TotalTokensOfAnswers'],), np.std, confidence_level=0.95).confidence_interval
# Out:
# ConfidenceInterval(low=2529.6710835647254, high=8671.629252392313)

# %%
bootstrap((non_error_issue['TotalNumberOfPrompts'],), np.std, confidence_level=0.95).confidence_interval
# Out:
# ConfidenceInterval(low=2.9952069388392046, high=11.164414676949669)

# %%
bootstrap((non_error_issue['NumberOfConversations'],), np.std, confidence_level=0.95).confidence_interval
# Out:
# ConfidenceInterval(low=2.6913098737990087, high=10.72084499620256)

# %%
bootstrap((non_error_issue['TotalTokensOfPrompts'],), np.std, confidence_level=0.95).confidence_interval
# Out:
# ConfidenceInterval(low=479.9947500656087, high=1250.6589828956587)

# %%
bootstrap((non_error_issue['TotalTokensOfAnswers'],), np.std, confidence_level=0.95).confidence_interval
# Out:
# ConfidenceInterval(low=932.5305362847714, high=3103.2823683789575)

# %%
non_error_commit.columns
# Out:
# Index(['Type', 'URL', 'Author', 'RepoName', 'RepoLanguage', 'Sha', 'Message',
#        'AuthorAt', 'CommitAt', 'NumberOfChatgptSharings',
#        'TotalNumberOfPrompts', 'TotalTokensOfPrompts', 'TotalTokensOfAnswers',
#        'NumberOfConversations', 'ModelGPT4', 'ModelGPT3_5', 'ModelOther',
#        'Status404', 'Sha_is_valid', 'author_timestamp', 'committer_timestamp',
#        'n_parents', 'is_merged_HEAD', 'number_of_commits_from_HEAD', 'error',
#        'change_lines_survived', 'change_lines_total',
#        'min_died_committer_timestamp'],
#       dtype='object')

# %%
issue_sharings_changes_survival_df.head()
# Out:
#     Type                                                URL     Author  \
# 0  issue  https://github.com/openactive/dataset-utils/is...     civsiv
# 1  issue  https://github.com/openactive/dataset-utils/is...     civsiv
# 2  issue  https://github.com/pionxzh/chatgpt-exporter/is...  kyoyacchi
# 3  issue  https://github.com/pionxzh/chatgpt-exporter/is...  kyoyacchi
# 4  issue  https://github.com/clojure-emacs/orchard/issue...       vemv
#
#                    RepoName RepoLanguage  Number  \
# 0  openactive/dataset-utils         HTML       2
# 1  openactive/dataset-utils         HTML       2
# 2  pionxzh/chatgpt-exporter   TypeScript     168
# 3  pionxzh/chatgpt-exporter   TypeScript     168
# 4     clojure-emacs/orchard      Clojure     186
#
#                                                Title  \
# 0  Add tests to https://github.com/openactive/dat...
# 1  Add tests to https://github.com/openactive/dat...
# 2                Broken view on share links (mobile)
# ...

# %%
non_error_commit.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 non_error_commit.head()
#
# NameError: name 'non_error_commit' is not defined

# %%
non_error_commit.columns
# Out:
# Index(['Type', 'URL', 'Author', 'RepoName', 'RepoLanguage', 'Sha', 'Message',
#        'AuthorAt', 'CommitAt', 'NumberOfChatgptSharings',
#        'TotalNumberOfPrompts', 'TotalTokensOfPrompts', 'TotalTokensOfAnswers',
#        'NumberOfConversations', 'ModelGPT4', 'ModelGPT3_5', 'ModelOther',
#        'Status404', 'Sha_is_valid', 'author_timestamp', 'committer_timestamp',
#        'n_parents', 'is_merged_HEAD', 'number_of_commits_from_HEAD', 'error',
#        'change_lines_survived', 'change_lines_total',
#        'min_died_committer_timestamp'],
#       dtype='object')

# %%
def f95(x):
    return x.quantile(0.95)

# %%
non_error_commit[['NumberOfChatgptSharings','TotalNumberOfPrompts','NumberOfConversations','change_lines_total']].agg(['count','min','median','max']).transpose()
# Out:
#                          count  min  median      max
# NumberOfChatgptSharings  691.0  1.0     1.0      1.0
# TotalNumberOfPrompts     691.0  0.0     1.0     64.0
# NumberOfConversations    691.0  0.0     1.0     63.0
# change_lines_total       691.0  0.0    79.0  77344.0

# %%
non_error_pr[['NumberOfChatgptSharings','TotalNumberOfPrompts','NumberOfConversations','change_lines_total']].agg(['count','min','median','max']).transpose()
# Out:
#                          count  min  median      max
# NumberOfChatgptSharings  182.0  1.0     1.0      4.0
# TotalNumberOfPrompts     182.0  0.0     2.0    167.0
# NumberOfConversations    182.0  0.0     1.0    166.0
# change_lines_total       182.0  0.0   103.5  53896.0

# %%
non_error_issue[['NumberOfChatgptSharings','TotalNumberOfPrompts','NumberOfConversations','change_lines_total']].agg(['count','min','median','max']).transpose()
# Out:
#                          count  min  median      max
# NumberOfChatgptSharings   69.0  1.0     1.0      4.0
# TotalNumberOfPrompts      69.0  0.0     2.0     42.0
# NumberOfConversations     69.0  0.0     2.0     39.0
# change_lines_total        69.0  2.0    69.0  31134.0

# %%
non_error_issue[['NumberOfChatgptSharings','TotalNumberOfPrompts','NumberOfConversations','change_lines_total']].agg(['count','min','median','max']).transpose().to_latex()
# Out:
# '\\begin{tabular}{lrrrr}\n\\toprule\n & count & min & median & max \\\\\n\\midrule\nNumberOfChatgptSharings & 69.000000 & 1.000000 & 1.000000 & 4.000000 \\\\\nTotalNumberOfPrompts & 69.000000 & 0.000000 & 2.000000 & 42.000000 \\\\\nNumberOfConversations & 69.000000 & 0.000000 & 2.000000 & 39.000000 \\\\\nchange_lines_total & 69.000000 & 2.000000 & 69.000000 & 31134.000000 \\\\\n\\bottomrule\n\\end{tabular}\n'

# %%
commit_describe = non_error_commit[['TotalNumberOfPrompts','TotalTokensOfPrompts','TotalTokensOfAnswers', 'NumberOfConversations','change_lines_survived','change_lines_total']].describe()

# %%
pr_describe = non_error_pr[['TotalNumberOfPrompts','TotalTokensOfPrompts','TotalTokensOfAnswers', 'NumberOfConversations','change_lines_survived','change_lines_total']].describe()

# %%
issue_describe = non_error_issue[['TotalNumberOfPrompts','TotalTokensOfPrompts','TotalTokensOfAnswers', 'NumberOfConversations','change_lines_survived','change_lines_total']].describe()

# %%
issue_describe = issue_describe.transpose()

# %%
issue_describe['Source'] = 'Issue'

# %%
commit_describe =commit_describe.transpose()

# %%
commit_describe['Source'] = 'Commit'

# %%
pr_describe = pr_describe.transpose()

# %%
pr_describe['Source']='Pull Request'

# %%
combined_describe = pd.concat([commit_describe,issue_describe,pr_describe])

# %%
combined_describe
# Out:
#                        count         mean          std  min     25%    50%  \
# TotalNumberOfPrompts   691.0     2.797395     4.868954  0.0    1.00    1.0
# TotalTokensOfPrompts   691.0   843.803184   908.829079  0.0  514.50  705.0
# TotalTokensOfAnswers   691.0   963.052098  1682.335165  0.0  327.00  522.0
# NumberOfConversations  691.0     2.337192     4.695115  0.0    1.00    1.0
# change_lines_survived  691.0   188.920405  2955.876717  0.0    2.00   18.0
# change_lines_total     691.0   245.610709  2966.866913  0.0   41.00   79.0
# TotalNumberOfPrompts    69.0     3.811594     5.834168  0.0    1.00    2.0
# TotalTokensOfPrompts    69.0   434.565217   800.356143  0.0   46.00  147.0
# TotalTokensOfAnswers    69.0  1127.942029  1717.617929  0.0  391.00  627.0
# NumberOfConversations   69.0     3.159420     5.405942  0.0    1.00    2.0
# change_lines_survived   69.0   970.550725  4037.193083  0.0   21.00   56.0
# ...

# %%
pr_sharings_changes_survival_df[pr_sharings_changes_survival_df['change_lines_total']==0.0]
# Out:
#              Type                                                URL  \
# 12   pull request  https://github.com/WalletConnect/echo-server/p...
# 57   pull request  https://github.com/aemartinez/gpt-latex-transl...
# 59   pull request  https://github.com/rhysmorgan134/node-CarPlay/...
# 73   pull request  https://github.com/JJConsulting/JJMasterData/p...
# 108  pull request  https://github.com/SWM14-Architect/moview-core...
# 116  pull request       https://github.com/KudoAI/chatgpt.js/pull/92
# 118  pull request        https://github.com/daydule/frontend/pull/35
# 181  pull request           https://github.com/openai/evals/pull/771
# 196  pull request         https://github.com/decred/dcrdex/pull/2333
# 204  pull request          https://github.com/mindee/doctr/pull/1205
#
#              Author                             RepoName RepoLanguage  Number  \
# 12      geekbrother            WalletConnect/echo-server         Rust     235
# ...

# %%
commit_sharings_changes_survival_df[commit_sharings_changes_survival_df['change_lines_total']==0.0]
# Out:
#        Type                                                URL  \
# 413  commit  https://github.com/mapi223/JUMPlus/commit/7c08...
# 547  commit  https://github.com/DuarteSerrao/TS/commit/b4c5...
#
#                Author         RepoName      RepoLanguage  \
# 413           mapi223  mapi223/JUMPlus  Jupyter Notebook
# 547  vascoliveira2511  DuarteSerrao/TS            Python
#
#                                           Sha  \
# 413  7c0861d23e9f79b112238015cfbca99f179cfbe0
# 547  b4c5a6a961c121537b6261924f8a1052dc58161f
#
#                                                Message  \
# 413  Add files via upload\n\nI also did this in Cha...
# 547  Tentei ecorporar o syslog, nao sei se funciona...
#
#                           AuthorAt                       CommitAt  \
# 413  2023-08-08T15:26:33.000-05:00  2023-08-08T15:26:33.000-05:00
# 547  2023-06-06T18:35:52.000+01:00  2023-06-06T18:35:52.000+01:00
#
#      NumberOfChatgptSharings  ...  Sha_is_valid  author_timestamp  \
# ...

# %%
pr_sharings_changes_survival_df[pr_sharings_changes_survival_df['TotalNumberOfPrompts']==0.0]
# Out:
#              Type                                                URL  \
# 12   pull request  https://github.com/WalletConnect/echo-server/p...
# 57   pull request  https://github.com/aemartinez/gpt-latex-transl...
# 59   pull request  https://github.com/rhysmorgan134/node-CarPlay/...
# 73   pull request  https://github.com/JJConsulting/JJMasterData/p...
# 108  pull request  https://github.com/SWM14-Architect/moview-core...
# 116  pull request       https://github.com/KudoAI/chatgpt.js/pull/92
# 118  pull request        https://github.com/daydule/frontend/pull/35
# 181  pull request           https://github.com/openai/evals/pull/771
# 196  pull request         https://github.com/decred/dcrdex/pull/2333
# 204  pull request          https://github.com/mindee/doctr/pull/1205
#
#              Author                             RepoName RepoLanguage  Number  \
# 12      geekbrother            WalletConnect/echo-server         Rust     235
# ...

# %%
commit_sharings_changes_survival_df[commit_sharings_changes_survival_df['TotalNumberOfPrompts']==0.0]
# Out:
#        Type                                                URL  \
# 413  commit  https://github.com/mapi223/JUMPlus/commit/7c08...
# 547  commit  https://github.com/DuarteSerrao/TS/commit/b4c5...
#
#                Author         RepoName      RepoLanguage  \
# 413           mapi223  mapi223/JUMPlus  Jupyter Notebook
# 547  vascoliveira2511  DuarteSerrao/TS            Python
#
#                                           Sha  \
# 413  7c0861d23e9f79b112238015cfbca99f179cfbe0
# 547  b4c5a6a961c121537b6261924f8a1052dc58161f
#
#                                                Message  \
# 413  Add files via upload\n\nI also did this in Cha...
# 547  Tentei ecorporar o syslog, nao sei se funciona...
#
#                           AuthorAt                       CommitAt  \
# 413  2023-08-08T15:26:33.000-05:00  2023-08-08T15:26:33.000-05:00
# 547  2023-06-06T18:35:52.000+01:00  2023-06-06T18:35:52.000+01:00
#
#      NumberOfChatgptSharings  ...  Sha_is_valid  author_timestamp  \
# ...

# %%
combined_describe.to_csv('combined_describe_survival.csv')

# %%
combined_describe
# Out:
#                        count         mean          std  min     25%    50%  \
# TotalNumberOfPrompts   691.0     2.797395     4.868954  0.0    1.00    1.0
# TotalTokensOfPrompts   691.0   843.803184   908.829079  0.0  514.50  705.0
# TotalTokensOfAnswers   691.0   963.052098  1682.335165  0.0  327.00  522.0
# NumberOfConversations  691.0     2.337192     4.695115  0.0    1.00    1.0
# change_lines_survived  691.0   188.920405  2955.876717  0.0    2.00   18.0
# change_lines_total     691.0   245.610709  2966.866913  0.0   41.00   79.0
# TotalNumberOfPrompts    69.0     3.811594     5.834168  0.0    1.00    2.0
# TotalTokensOfPrompts    69.0   434.565217   800.356143  0.0   46.00  147.0
# TotalTokensOfAnswers    69.0  1127.942029  1717.617929  0.0  391.00  627.0
# NumberOfConversations   69.0     3.159420     5.405942  0.0    1.00    2.0
# change_lines_survived   69.0   970.550725  4037.193083  0.0   21.00   56.0
# ...

# %%
non_error[['TotalNumberOfPrompts','NumberOfConversations','change_lines_survived','change_lines_total']].quantile([0.95])
# Out:
#       TotalNumberOfPrompts  NumberOfConversations  change_lines_survived  \
# 0.95                  10.0                    9.0                  211.0
#
#       change_lines_total
# 0.95               254.5

# %%
import seaborn as sns

# %%
sns.histplot(non_error[non_error['is_merged_HEAD']==True], x='TotalNumberOfPrompts')
# Out:
# <Axes: xlabel='TotalNumberOfPrompts', ylabel='Count'>

# %%
sns.histplot(non_error[non_error['is_merged_HEAD']==True], x='NumberOfConversations')
# Out:
# <Axes: xlabel='NumberOfConversations', ylabel='Count'>

# %%
sns.histplot(non_error[non_error['is_merged_HEAD']==True], x='change_lines_survived')
# Out:
# <Axes: xlabel='change_lines_survived', ylabel='Count'>

# %%
sns.histplot(non_error[(non_error['is_merged_HEAD']==True)&(non_error['change_lines_survived']<211.0)], x='change_lines_survived')
# Out:
# <Axes: xlabel='change_lines_survived', ylabel='Count'>

# %%
sns.histplot(non_error[(non_error['is_merged_HEAD']==True)&(non_error['change_lines_total']<254.5)], x='change_lines_total')
# Out:
# <Axes: xlabel='change_lines_total', ylabel='Count'>

# %%
sns.histplot(non_error_pr[(non_error_pr['is_merged_HEAD']==True)&(non_error_pr['change_lines_survived']<5000)], x='change_lines_survived')
# Out:
# <Axes: xlabel='change_lines_survived', ylabel='Count'>

# %%
sns.histplot(non_error_pr[(non_error_pr['is_merged_HEAD']==True)&(non_error_pr['change_lines_total']<5000)], x='change_lines_total')
# Out:
# <Axes: xlabel='change_lines_total', ylabel='Count'>

# %%
sns.histplot(non_error_issue[(non_error_issue['is_merged_HEAD']==True)&(non_error_issue['change_lines_total']<5000)], x='change_lines_total')
# Out:
# <Axes: xlabel='change_lines_total', ylabel='Count'>

# %%
sns.histplot(non_error_issue[(non_error_issue['is_merged_HEAD']==True)&(non_error_issue['change_lines_survived']<5000)], x='change_lines_survived')
# Out:
# <Axes: xlabel='change_lines_survived', ylabel='Count'>
